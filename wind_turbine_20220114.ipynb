# %%
import pandas as pd

wind = pd.read_csv('wind_turbine_20220114.csv', encoding = "latin1")

# %%
wind.head(10)
# Out:
#    case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0  3072661        NaN               NaN      5149.0  52161.0      CA
# 1  3072695        NaN               NaN      5143.0  52161.0      CA
# 2  3072704        NaN               NaN      5146.0  52161.0      CA
# 3  3063272  19-028134  2014-WTE-4084-OE         NaN      NaN      IA
# 4  3053390  19-028015  2015-WTE-6386-OE         NaN      NaN      IA
# 5  3063269  19-028130  2016-WTE-5934-OE         NaN      NaN      IA
# 6  3049500  19-028030  2014-WTE-4080-OE         NaN      NaN      IA
# 7  3049502  19-027953  2014-WTE-4082-OE         NaN      NaN      IA
# 8  3063321  19-028135  2014-WTE-4087-OE         NaN      NaN      IA
# 9  3049503  19-028064  2014-WTE-4083-OE         NaN      NaN      IA
#
#         t_county  t_fips                   p_name  p_year  ...     t_rsa  \
# 0    Kern County    6029                 251 Wind  1987.0  ...       NaN
# ...

# %%
wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70808 entries, 0 to 70807
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   case_id        70808 non-null  int64
#  1   faa_ors        65016 non-null  object
#  2   faa_asn        65686 non-null  object
#  3   usgs_pr_id     38263 non-null  float64
#  4   eia_id         65015 non-null  float64
#  5   t_state        70808 non-null  object
#  6   t_county       70808 non-null  object
#  7   t_fips         70808 non-null  int64
#  8   p_name         70808 non-null  object
#  9   p_year         70195 non-null  float64
#  10  p_tnum         70808 non-null  int64
#  11  p_cap          66326 non-null  float64
#  12  t_manu         65168 non-null  object
#  13  t_model        65031 non-null  object
#  14  t_cap          65328 non-null  float64
#  15  t_hh           64628 non-null  float64
#  16  t_rd           64874 non-null  float64
# ...

# %%
wind.isnull().sum().sort_values(ascending=False)
# Out:
# retrofit_year    64822
# usgs_pr_id       32545
# t_img_date        8316
# t_ttlh            6180
# t_hh              6180
# t_rsa             5934
# t_rd              5934
# eia_id            5793
# faa_ors           5792
# t_model           5777
# t_manu            5640
# t_cap             5480
# faa_asn           5122
# p_cap             4482
# p_year             613
# t_conf_atr           0
# t_conf_loc           0
# t_img_srce           0
# xlong                0
# case_id              0
# retrofit             0
# p_tnum               0
# p_name               0
# t_fips               0
# t_county             0
# t_state              0
# ylat                 0
# dtype: int64

# %%
wind.case_id.nunique()
# Out:
# 70808

# %%
wind.duplicated(keep=False).sum()
# Out:
# 0

# %%
wind['t_img_date'] = pd.to_datetime(wind.t_img_date, dayfirst=False)

# %%
wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70808 entries, 0 to 70807
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   case_id        70808 non-null  int64
#  1   faa_ors        65016 non-null  object
#  2   faa_asn        65686 non-null  object
#  3   usgs_pr_id     38263 non-null  float64
#  4   eia_id         65015 non-null  float64
#  5   t_state        70808 non-null  object
#  6   t_county       70808 non-null  object
#  7   t_fips         70808 non-null  int64
#  8   p_name         70808 non-null  object
#  9   p_year         70195 non-null  float64
#  10  p_tnum         70808 non-null  int64
#  11  p_cap          66326 non-null  float64
#  12  t_manu         65168 non-null  object
#  13  t_model        65031 non-null  object
#  14  t_cap          65328 non-null  float64
#  15  t_hh           64628 non-null  float64
#  16  t_rd           64874 non-null  float64
# ...

# %%
wind.set_index('case_id', inplace=True)

# %%
wind.head()
# Out:
#            faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# case_id
# 3072661        NaN               NaN      5149.0  52161.0      CA
# 3072695        NaN               NaN      5143.0  52161.0      CA
# 3072704        NaN               NaN      5146.0  52161.0      CA
# 3063272  19-028134  2014-WTE-4084-OE         NaN      NaN      IA
# 3053390  19-028015  2015-WTE-6386-OE         NaN      NaN      IA
#
#              t_county  t_fips                   p_name  p_year  p_tnum  ...  \
# case_id                                                                 ...
# 3072661   Kern County    6029                 251 Wind  1987.0     194  ...
# 3072695   Kern County    6029                 251 Wind  1987.0     194  ...
# 3072704   Kern County    6029                 251 Wind  1987.0     194  ...
# 3063272  Story County   19169  30 MW Iowa DG Portfolio  2017.0      10  ...
# 3053390  Boone County   19015  30 MW Iowa DG Portfolio  2017.0      10  ...
#
# ...

# %%
wind_clean = wind.drop(columns=['faa_ors', 'faa_asn', 'usgs_pr_id', 't_fips'])

# %%
wind_clean.head()
# Out:
#           eia_id t_state      t_county                   p_name  p_year  \
# case_id
# 3072661  52161.0      CA   Kern County                 251 Wind  1987.0
# 3072695  52161.0      CA   Kern County                 251 Wind  1987.0
# 3072704  52161.0      CA   Kern County                 251 Wind  1987.0
# 3063272      NaN      IA  Story County  30 MW Iowa DG Portfolio  2017.0
# 3053390      NaN      IA  Boone County  30 MW Iowa DG Portfolio  2017.0
#
#          p_tnum  p_cap  t_manu     t_model   t_cap  ...     t_rsa  t_ttlh  \
# case_id                                             ...
# 3072661     194  18.43  Vestas         NaN    95.0  ...       NaN     NaN
# 3072695     194  18.43  Vestas         NaN    95.0  ...       NaN     NaN
# 3072704     194  18.43  Vestas         NaN    95.0  ...       NaN     NaN
# 3063272      10  30.00  Nordex  AW125/3000  3000.0  ...  12271.85   150.0
# 3053390      10  30.00  Nordex  AW125/3000  3000.0  ...  12271.85   150.0
#
# ...

# %%
wind_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70808 entries, 3072661 to 3055917
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   eia_id         65015 non-null  float64
#  1   t_state        70808 non-null  object
#  2   t_county       70808 non-null  object
#  3   p_name         70808 non-null  object
#  4   p_year         70195 non-null  float64
#  5   p_tnum         70808 non-null  int64
#  6   p_cap          66326 non-null  float64
#  7   t_manu         65168 non-null  object
#  8   t_model        65031 non-null  object
#  9   t_cap          65328 non-null  float64
#  10  t_hh           64628 non-null  float64
#  11  t_rd           64874 non-null  float64
#  12  t_rsa          64874 non-null  float64
#  13  t_ttlh         64628 non-null  float64
#  14  retrofit       70808 non-null  int64
#  15  retrofit_year  5986 non-null   float64
#  16  t_conf_atr     70808 non-null  int64
# ...

# %%
wind_clean.sample(10)
# Out:
#           eia_id t_state            t_county  \
# case_id
# 3106058      NaN      WY       Carbon County
# 3035557  56665.0      OK  Roger Mills County
# 3052911  58767.0      KS        Ellis County
# 3052994  60342.0      IA          Ida County
# 3054229  60592.0      OK        Grady County
# 3100604  50533.0      CA    Riverside County
# 3024929  56773.0      TX      Dickens County
# 3086630  61564.0      IA         Clay County
# 3045089  56377.0      MT    Wheatland County
# 3048375  58838.0      TX         Jack County
#
#                                        p_name  p_year  p_tnum   p_cap  \
# case_id
# 3106058                       TB Flats I & II  2021.0     132  503.20
# 3035557  Big Smile Wind Farm at Dempsey Ridge  2012.0      66  132.00
# 3052911                               Buckeye  2015.0     112  200.00
# 3052994                             Ida Grove  2016.0     134  301.06
# 3054229       Rush Springs Wind Energy Center  2016.0     120  249.00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
wind_clean.groupby('p_year')['p_year'].value_counts()
# Out:
# p_year
# 1981.0      10
# 1982.0     930
# 1983.0     433
# 1984.0     155
# 1985.0     516
# 1986.0      79
# 1987.0     193
# 1988.0     162
# 1989.0     288
# 1990.0       1
# 1991.0       1
# 1992.0       2
# 1994.0      10
# 1995.0      21
# 1996.0      14
# 1997.0     230
# 1998.0     186
# 1999.0     618
# 2000.0      72
# 2001.0    1870
# 2002.0     461
# 2003.0    1152
# 2004.0     268
# 2005.0    1638
# 2006.0    1418
# 2007.0    3200
# 2008.0    5047
# 2009.0    5701
# 2010.0    2962
# 2011.0    3497
# 2012.0    6768
# 2013.0     600
# 2014.0    2506
# 2015.0    4301
# 2016.0    3798
# 2017.0    3058
# 2018.0    3136
# 2019.0    3588
# 2020.0    6592
# 2021.0    4713
# Name: count, dtype: int64

# %%
wind_clean.isnull().sum()
# Out:
# eia_id            5793
# t_state              0
# t_county             0
# p_name               0
# p_year             613
# p_tnum               0
# p_cap             4482
# t_manu            5640
# t_model           5777
# t_cap             5480
# t_hh              6180
# t_rd              5934
# t_rsa             5934
# t_ttlh            6180
# retrofit             0
# retrofit_year    64822
# t_conf_atr           0
# t_conf_loc           0
# t_img_date        8316
# t_img_srce           0
# xlong                0
# ylat                 0
# dtype: int64

# %%
pd.DataFrame(wind_clean.columns)
# Out:
#                 0
# 0          eia_id
# 1         t_state
# 2        t_county
# 3          p_name
# 4          p_year
# 5          p_tnum
# 6           p_cap
# 7          t_manu
# 8         t_model
# 9           t_cap
# 10           t_hh
# 11           t_rd
# 12          t_rsa
# 13         t_ttlh
# 14       retrofit
# 15  retrofit_year
# 16     t_conf_atr
# 17     t_conf_loc
# 18     t_img_date
# 19     t_img_srce
# 20          xlong
# 21           ylat

# %%
wind_clean.rename(columns={'t_state':'state'
,'t_county':'county'
,'p_name':'wind_farm'
,'p_year':'year'
,'p_tnum':'turbine_count'
,'p_cap':'project_capacity'
,'t_manu':'manufact'
,'t_model':'model'
,'t_cap':'turbine_capacity'
,'t_hh':'hub_height'
,'t_rd':'rotor_diameter'
,'t_rsa':'rotor_swept_area'
,'t_ttlh':'total_height'
,'retrofit':'retrofit'
,'retrofit_year':'retrofit_year'
,'t_conf_atr':'conf_atr'
,'t_conf_loc':'conf_loc'
,'t_img_date':'img_date'
,'t_img_srce':'img_source'
,'xlong':'long'
,'ylat':'lat'},inplace=True)

pd.DataFrame(wind_clean.columns)
# Out:
#                    0
# 0             eia_id
# 1              state
# 2             county
# 3          wind_farm
# 4               year
# 5      turbine_count
# 6   project_capacity
# 7           manufact
# 8              model
# 9   turbine_capacity
# 10        hub_height
# 11    rotor_diameter
# 12  rotor_swept_area
# 13      total_height
# 14          retrofit
# 15     retrofit_year
# 16          conf_atr
# 17          conf_loc
# 18          img_date
# 19        img_source
# 20              long
# 21               lat

# %%
wind_clean.groupby('year')['turbine_count'].sum().plot(figsize=(16,10))
# Out:
# <Axes: xlabel='year'>

# %%
wind_clean.describe()
# Out:
#              eia_id          year  turbine_count  project_capacity  \
# count  65015.000000  70195.000000   70808.000000      66326.000000
# mean   57877.751642   2011.650659     104.360552        170.176128
# min       90.000000   1981.000000       1.000000          0.050000
# 25%    56763.000000   2008.000000      56.000000         99.000000
# 50%    57752.000000   2012.000000      85.000000        158.000000
# 75%    60338.000000   2018.000000     121.000000        211.220000
# max    65270.000000   2021.000000     731.000000        525.020000
# std     5984.516487      7.879099      93.954786        104.478693
#
#        turbine_capacity    hub_height  rotor_diameter  rotor_swept_area  \
# count      65328.000000  64628.000000    64874.000000      64874.000000
# mean        1963.534151     81.054571       95.663717       7618.500657
# min           50.000000     19.000000       13.400000        141.030000
# 25%         1500.000000     80.000000       82.000000       5281.020000
# ...

# %%
count_year = wind_clean.groupby('year')['turbine_count'].sum()
count_year =count_year.cumsum(axis=0)

# %%
count_year
# Out:
# year
# 1981.0       7310
# 1982.0     567869
# 1983.0     766594
# 1984.0     786545
# 1985.0     887269
# 1986.0     892689
# 1987.0     940771
# 1988.0     967498
# 1989.0    1053034
# 1990.0    1053181
# 1991.0    1053182
# 1992.0    1053331
# 1994.0    1053991
# 1995.0    1054832
# 1996.0    1055314
# 1997.0    1100751
# 1998.0    1122093
# 1999.0    1169065
# 2000.0    1170368
# 2001.0    1515394
# 2002.0    1575303
# 2003.0    1666346
# 2004.0    1682871
# 2005.0    1811048
# 2006.0    1935402
# 2007.0    2326741
# 2008.0    2743882
# 2009.0    3220459
# 2010.0    3440124
# 2011.0    3716750
# 2012.0    4310746
# 2013.0    4351573
# 2014.0    4591461
# 2015.0    5022250
# 2016.0    5364772
# 2017.0    5626040
# 2018.0    5882955
# 2019.0    6241622
# 2020.0    6880311
# 2021.0    7355980
# Name: turbine_count, dtype: int64

# %%
wind_clean.turbine_count.sum()
# Out:
# 7389562

# %%
count_year.plot(figsize=(16,10))
# Out:
# <Axes: xlabel='year'>

# %%
wind_clean.corr(numeric_only=True)
# Out:
#                     eia_id      year  turbine_count  project_capacity  \
# eia_id            1.000000  0.633978      -0.127118          0.330798
# year              0.633978  1.000000      -0.459555          0.471276
# turbine_count    -0.127118 -0.459555       1.000000          0.461287
# project_capacity  0.330798  0.471276       0.461287          1.000000
# turbine_capacity  0.469556  0.742803      -0.314949          0.367990
# hub_height        0.486243  0.750585      -0.320060          0.315461
# rotor_diameter    0.582939  0.891214      -0.245392          0.453465
# rotor_swept_area  0.547907  0.850167      -0.188024          0.446108
# total_height      0.568684  0.866857      -0.299498          0.402049
# retrofit         -0.073645 -0.199159      -0.009980         -0.049124
# retrofit_year     0.220068  0.368512      -0.382057         -0.328581
# conf_atr          0.408852  0.172143      -0.256083          0.132691
# ...

# %%
wind_clean.dropna(subset=['year'], inplace=True)

# %%
wind_clean.to_csv('wind.csv')

# %%
count_year.to_csv('cumulative_count.csv')
